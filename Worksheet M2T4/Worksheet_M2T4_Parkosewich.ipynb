# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file = open('./adult.data', 'r')
def chr_int(a):
    if a.isdigit(): return int(a)
    else: return 0

data = []
for line in file:
    data1 = line.split(', ')
    if len(data1) == 15:
        data.append([
            chr_int(data1[0]), data1[1],
            chr_int(data1[2]), data1[3],
            chr_int(data1[4]), data1[5],
            data1[6], data1[7], data1[8],
            data1[9], chr_int(data1[10]),
            chr_int(data1[11]),
            chr_int(data1[12]),
            data1[13], data1[14].strip()
        ])
adult = pd.DataFrame(
    data,
    columns = [
        'age', 'type-employer', 'fnlwgt',
        'education', 'education_num', 'marital',
        'occupation', 'relationship','race',
        'sex', 'capital_gain', 'capital_loss',
        'hr_per_week', 'country', 'income'
    ]

)
men = adult[adult['sex'] == "Male"]
women = adult[adult['sex'] == "Female"]
test_men = men[men['income'] == ">50k"]
men_high_income = adult[(adult['sex']=="Male") &(adult['income'] == ">50K")]
women_high_income = adult[(adult['sex']=="Female") &(adult['income'] == ">50K")]
men_low_income = adult[(adult['sex']=="Male") &(adult['income'] == "<=50K")]
women_low_income = adult[(adult['sex']=="Female") &(adult['income'] == "<=50K")]

# %% [markdown]
# # Question 1

# %%
print men['age'].mean()
print women['age'].mean()
print men_high_income['age'].mean()
print women_high_income['age'].mean()
# Out:
# 39.4335474989
# 36.8582304336
# 44.6257880516
# 42.1255301103

# %% [markdown]
# # Question 2

# %%
print men['age'].var()
print men['age'].std()
print women['age'].var()
print women['age'].std()
print men_high_income['age'].var()
print men_high_income['age'].std()
print women_high_income['age'].var()
print women_high_income['age'].std()
# Out:
# 178.773751745
# 13.3706301925
# 196.383706395
# 14.0136970994
# 109.945066749
# 10.4854693147
# 109.413770411
# 10.4601037476

# %% [markdown]
# # Question 3

# %% [markdown]
# Change the figsize parameter in hist()
# e.g. adult.hist(figsize = (10,10))

# %% [markdown]
# # Question 4

# %%
men.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C38A9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C5F75C0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C2DAD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C67B4E0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C735C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C775400>]],
#       dtype=object)

# %%
women.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000CC76AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CD140F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000CD42860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CDCAFD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000CE8E780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CF04EF0>]],
#       dtype=object)

# %%
men_high_income.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D02A390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D49DF60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D548710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D5BDE80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D63F630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D6FBDA0>]],
#       dtype=object)

# %%
women_high_income.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D7895F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DE13BE0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DDE9390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DF1AB00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DF582B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E00FA20>]],
#       dtype=object)

# %%
men_low_income.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E541278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E972EB8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E9D4668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EA8ADD8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000EB0D588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EB3ECF8>]],
#       dtype=object)

# %%
women_low_income.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DC780F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F14D7B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000F1A7F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F26A6D8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000F365E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F3A35F8>]],
#       dtype=object)

# %% [markdown]
# # Question 5

# %%
print men['age'].median()
print women['age'].median()
print men_high_income['age'].median()
print women_high_income['age'].median()
# Out:
# 38.0
# 35.0
# 44.0
# 41.0

# %% [markdown]
# # Question 6
#
# The 50th percentile is also called the median

# %% [markdown]
# # Question 7

# %%
def IQR(x):
    return x.quantile(.75) - x.quantile(.25)

# %%
print IQR(men['age'])
print IQR(women['age'])
print IQR(men_high_income['age'])
print IQR(women_high_income['age'])
# Out:
# 19.0
# 21.0
# 14.0
# 15.0
